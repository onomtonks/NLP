# %%
import spacy

# %%
nlp =spacy.load('en_core_web_sm')

# %%
doc = nlp("Elon flew to mars yesterday.He ate Andai Wala Burger there.")
for token in doc:
  print(token,'|',token.pos_,"|",spacy.explain(token.pos_),"|",token.tag_,"|",spacy.explain(token.tag_))
# Out:
# Elon | PROPN | proper noun | NNP | noun, proper singular
# flew | VERB | verb | VBD | verb, past tense
# to | ADP | adposition | IN | conjunction, subordinating or preposition
# mars | NOUN | noun | NNS | noun, plural
# yesterday | NOUN | noun | NN | noun, singular or mass
# . | PUNCT | punctuation | . | punctuation mark, sentence closer
# He | PRON | pronoun | PRP | pronoun, personal
# ate | VERB | verb | VBD | verb, past tense
# Andai | PROPN | proper noun | NNP | noun, proper singular
# Wala | PROPN | proper noun | NNP | noun, proper singular
# Burger | PROPN | proper noun | NNP | noun, proper singular
# there | ADV | adverb | RB | adverb
# . | PUNCT | punctuation | . | punctuation mark, sentence closer

# %%
earnings_text="""Microsoft Corp. today announced the following results for the quarter ended December 31, 2021, as compared to the corresponding period of last fiscal year:

·         Revenue was $51.7 billion and increased 20%
·         Operating income was $22.2 billion and increased 24%
·         Net income was $18.8 billion and increased 21%
·         Diluted earnings per share was $2.48 and increased 22%
“Digital technology is the most malleable resource at the world’s disposal to overcome constraints and reimagine everyday work and life,” said Satya Nadella, chairman and chief executive officer of Microsoft. “As tech as a percentage of global GDP continues to increase, we are innovating and investing across diverse and growing markets, with a common underlying technology stack and an operating model that reinforces a common strategy, culture, and sense of purpose.”
“Solid commercial execution, represented by strong bookings growth driven by long-term Azure commitments, increased Microsoft Cloud revenue to $22.1 billion, up 32% year over year” said Amy Hood, executive vice president and chief financial officer of Microsoft."""

# %%
doc = nlp(earnings_text)

for token in doc:
  if token.pos_ not in ["SACE",'X',"PUNCT"]:
    print(token,'|',token.pos_,'|',spacy.explain(token.pos_))
# Out:
# Microsoft | PROPN | proper noun
# Corp. | PROPN | proper noun
# today | NOUN | noun
# announced | VERB | verb
# the | DET | determiner
# following | VERB | verb
# results | NOUN | noun
# for | ADP | adposition
# the | DET | determiner
# quarter | NOUN | noun
# ended | VERB | verb
# December | PROPN | proper noun
# 31 | NUM | numeral
# 2021 | NUM | numeral
# as | SCONJ | subordinating conjunction
# compared | VERB | verb
# to | ADP | adposition
# the | DET | determiner
# corresponding | ADJ | adjective
# period | NOUN | noun
# of | ADP | adposition
# last | ADJ | adjective
# fiscal | ADJ | adjective
# year | NOUN | noun
#
#
#  | SPACE | space
#          | SPACE | space
# Revenue | PROPN | proper noun
# was | AUX | auxiliary
# $ | SYM | symbol
# 51.7 | NUM | numeral
# billion | NUM | numeral
# and | CCONJ | coordinating conjunction
# increased | VERB | verb
# 20 | NUM | numeral
# % | NOUN | noun
#
#  | SPACE | space
#          | SPACE | space
# Operating | NOUN | noun
# income | NOUN | noun
# was | AUX | auxiliary
# $ | SYM | symbol
# 22.2 | NUM | numeral
# billion | NUM | numeral
# and | CCONJ | coordinating conjunction
# increased | VERB | verb
# 24 | NUM | numeral
# % | NOUN | noun
#
#  | SPACE | space
#          | SPACE | space
# Net | ADJ | adjective
# income | NOUN | noun
# was | AUX | auxiliary
# $ | SYM | symbol
# 18.8 | NUM | numeral
# billion | NUM | numeral
# and | CCONJ | coordinating conjunction
# increased | VERB | verb
# 21 | NUM | numeral
# % | NOUN | noun
#
#  | SPACE | space
#          | SPACE | space
# Diluted | VERB | verb
# earnings | NOUN | noun
# per | ADP | adposition
# share | NOUN | noun
# was | AUX | auxiliary
# $ | SYM | symbol
# 2.48 | NUM | numeral
# and | CCONJ | coordinating conjunction
# increased | VERB | verb
# 22 | NUM | numeral
# % | NOUN | noun
#
#  | SPACE | space
# Digital | PROPN | proper noun
# technology | NOUN | noun
# is | AUX | auxiliary
# the | DET | determiner
# most | ADV | adverb
# malleable | ADJ | adjective
# resource | NOUN | noun
# at | ADP | adposition
# the | DET | determiner
# world | NOUN | noun
# ’s | PART | particle
# disposal | NOUN | noun
# to | PART | particle
# overcome | VERB | verb
# constraints | NOUN | noun
# and | CCONJ | coordinating conjunction
# reimagine | VERB | verb
# everyday | ADJ | adjective
# work | NOUN | noun
# and | CCONJ | coordinating conjunction
# life | NOUN | noun
# said | VERB | verb
# Satya | PROPN | proper noun
# Nadella | PROPN | proper noun
# chairman | NOUN | noun
# and | CCONJ | coordinating conjunction
# chief | ADJ | adjective
# executive | ADJ | adjective
# officer | NOUN | noun
# of | ADP | adposition
# Microsoft | PROPN | proper noun
# As | ADV | adverb
# tech | ADJ | adjective
# as | ADP | adposition
# a | DET | determiner
# percentage | NOUN | noun
# of | ADP | adposition
# global | ADJ | adjective
# GDP | PROPN | proper noun
# continues | VERB | verb
# to | PART | particle
# increase | VERB | verb
# we | PRON | pronoun
# are | AUX | auxiliary
# innovating | VERB | verb
# and | CCONJ | coordinating conjunction
# investing | VERB | verb
# across | ADP | adposition
# diverse | ADJ | adjective
# and | CCONJ | coordinating conjunction
# growing | VERB | verb
# markets | NOUN | noun
# with | ADP | adposition
# a | DET | determiner
# common | ADJ | adjective
# underlying | VERB | verb
# technology | NOUN | noun
# stack | NOUN | noun
# and | CCONJ | coordinating conjunction
# an | DET | determiner
# operating | NOUN | noun
# model | NOUN | noun
# that | PRON | pronoun
# reinforces | VERB | verb
# a | DET | determiner
# common | ADJ | adjective
# strategy | NOUN | noun
# culture | NOUN | noun
# and | CCONJ | coordinating conjunction
# sense | NOUN | noun
# of | ADP | adposition
# purpose | NOUN | noun
#
#  | SPACE | space
# Solid | ADJ | adjective
# commercial | ADJ | adjective
# execution | NOUN | noun
# represented | VERB | verb
# by | ADP | adposition
# strong | ADJ | adjective
# bookings | NOUN | noun
# growth | NOUN | noun
# driven | VERB | verb
# by | ADP | adposition
# long | ADJ | adjective
# term | NOUN | noun
# Azure | PROPN | proper noun
# commitments | NOUN | noun
# increased | VERB | verb
# Microsoft | PROPN | proper noun
# Cloud | PROPN | proper noun
# revenue | NOUN | noun
# to | ADP | adposition
# $ | SYM | symbol
# 22.1 | NUM | numeral
# billion | NUM | numeral
# up | ADV | adverb
# 32 | NUM | numeral
# % | NOUN | noun
# year | NOUN | noun
# over | ADP | adposition
# year | NOUN | noun
# said | VERB | verb
# Amy | PROPN | proper noun
# Hood | PROPN | proper noun
# executive | ADJ | adjective
# vice | NOUN | noun
# president | NOUN | noun
# and | CCONJ | coordinating conjunction
# chief | ADJ | adjective
# financial | ADJ | adjective
# officer | NOUN | noun
# of | ADP | adposition
# Microsoft | PROPN | proper noun

# %%
count= doc.count_by(spacy.attrs.POS)
count
# Out:
# {96: 15,
#  92: 45,
#  100: 23,
#  90: 9,
#  85: 16,
#  93: 16,
#  97: 27,
#  98: 1,
#  84: 20,
#  103: 10,
#  87: 6,
#  99: 5,
#  89: 12,
#  86: 3,
#  94: 3,
#  95: 2}

# %%
doc.vocab[96].text
# Out:
# 'PROPN'

# %%
with open("news_story.txt") as f:
  n=f.read()

# %%
doc = nlp(n)
noun=[]
num=[]
for token in doc:
  if token.pos_ == "NOUN":
    noun.append(token)
  elif token.pos_ =='NUM':
    num.append(token)
# Out:
# [8.3,
#  8.1,
#  1982,
#  6.2,
#  6,
#  0.3,
#  0.2,
#  0.6,
#  0.4,
#  0.1,
#  0.3,
#  2.6,
#  5.5,
#  2021,
#  1984,
#  one,
#  two,
#  two,
#  2]

# %%
count= doc.count_by(spacy.attrs.POS)
new ={}
for i,j in count.items():
  new.update({doc.vocab[i].text:j})

new
# Out:
# {'NOUN': 96,
#  'VERB': 27,
#  'ADV': 15,
#  'ADP': 39,
#  'PROPN': 16,
#  'PUNCT': 32,
#  'DET': 34,
#  'PRON': 4,
#  'AUX': 13,
#  'CCONJ': 10,
#  'ADJ': 23,
#  'SPACE': 7,
#  'NUM': 19,
#  'PART': 4,
#  'SCONJ': 8,
#  'X': 1}

# %% [markdown]
# # New Section
